# %%
'''import pandas as pd
from google.colab import drive
'''
# Out:
# 'import pandas as pd\nfrom google.colab import drive\n'

# %%
'''drive.mount('/content/drive')'''
# Out:
# "drive.mount('/content/drive')"

# %%
'''path = "/content/drive/MyDrive/Colab Notebooks/Research Energy Consumption Production/Factors.csv"
df = pd.read_csv(path, header=1)
df
'''
# Out:
# 'path = "/content/drive/MyDrive/Colab Notebooks/Research Energy Consumption Production/Factors.csv"\ndf = pd.read_csv(path, header=1)\ndf\n'

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Factors.csv', header = 1)
df
# Out:
#     Years  Production (TJ)  Consumption (TJ)  Transportation (TJ)  \
# 0    1973             1600             84300                28400
# 1    1974             1000             93800                28400
# 2    1975              800             96000                30500
# 3    1976              400            103000                31900
# 4    1977              900            116300                35700
# 5    1978              900            122500                36500
# 6    1979              700            134900                40500
# 7    1980              500            134200                36400
# 8    1981              700            124300                35900
# 9    1982              600            129100                38700
# 10   1983              700            126000                37500
# 11   1984              600            124100                36100
# 12   1985              900            124600                36600
# ...

# %%
production = df['Production (TJ)']
consumption = df['Consumption (TJ)']
years = df['Years']
df = df.drop(columns = ['Years'])

# %%
df
# Out:
#     Production (TJ)  Consumption (TJ)  Transportation (TJ)  Industry  (TJ)  \
# 0              1600             84300                28400           42900
# 1              1000             93800                28400           49800
# 2               800             96000                30500           46100
# 3               400            103000                31900           50400
# 4               900            116300                35700           56500
# 5               900            122500                36500           60900
# 6               700            134900                40500           67500
# 7               500            134200                36400           71800
# 8               700            124300                35900           64700
# 9               600            129100                38700           64200
# 10              700            126000                37500           67400
# ...

# %% [markdown]
# prev_Years = np.array(prev_Years).reshape(-1, 1)
# prev_Years.shape

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
#Data for the Consumption Prediction
X_train = years[:-10]
X_test = years[-10:]
y_train = df[:-10]
y_test = df[-10:]
X_train = np.array(X_train).reshape(-1, 1)
X_train
# Out:
# array([[1973],
#        [1974],
#        [1975],
#        [1976],
#        [1977],
#        [1978],
#        [1979],
#        [1980],
#        [1981],
#        [1982],
#        [1983],
#        [1984],
#        [1985],
#        [1986],
#        [1987],
#        [1988],
#        [1989],
#        [1990],
#        [1991],
#        [1992],
#        [1993],
#        [1994],
#        [1995],
#        [1996],
#        [1997],
#        [1998],
#        [1999],
#        [2000],
#        [2001],
#        [2002],
#        [2003],
#        [2004],
#        [2005],
#        [2006],
#        [2007],
#        [2008],
#        [2009]], dtype=int64)

# %%
X_test = np.array(X_test).reshape(-1, 1)

# %%
X_test
# Out:
# array([[2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018],
#        [2019]], dtype=int64)

# %% [markdown]
# **Linear Regression**

# %%
Linear_model = LinearRegression()
Linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_Linear = Linear_model.predict(X_test)

# %%
predicted_Linear = pd.DataFrame(predicted_Linear)
predicted_Linear
# Out:
#            0              1              2              3             4   \
# 0  266.504505  328227.833333  152259.909910  111250.450450  42430.630631
# 1  249.663348  335510.636795  156253.247985  112910.431484  42784.305358
# 2  232.822191  342793.440256  160246.586060  114570.412518  43137.980085
# 3  215.981034  350076.243717  164239.924135  116230.393551  43491.654813
# 4  199.139877  357359.047179  168233.262210  117890.374585  43845.329540
# 5  182.298720  364641.850640  172226.600284  119550.355619  44199.004267
# 6  165.457563  371924.654101  176219.938359  121210.336652  44552.678995
# 7  148.616406  379207.457563  180213.276434  122870.317686  44906.353722
# 8  131.775249  386490.261024  184206.614509  124530.298720  45260.028450
# 9  114.934092  393773.064486  188199.952584  126190.279753  45613.703177
#
#              5         6          7          8            9             10  \
# 0  76710.360360  0.950766  47.091351  70.970878  1630.387387  12009.948649
# ...

# %%
predicted_Linear_next = Linear_model.predict(next_years)
predicted_Linear_next = pd.DataFrame(predicted_Linear_next)
predicted_Linear_next
# Out:
#             0              1              2              3             4   \
# 0    64.410621  415621.474870  200179.966809  131170.222854  46674.727359
# 1    47.569464  422904.278331  204173.304884  132830.203888  47028.402086
# 2    30.728307  430187.081792  208166.642959  134490.184922  47382.076814
# 3    13.887150  437469.885254  212159.981034  136150.165955  47735.751541
# 4    -2.954007  444752.688715  216153.319109  137810.146989  48089.426268
# 5   -19.795164  452035.492176  220146.657183  139470.128023  48443.100996
# 6   -36.636321  459318.295638  224139.995258  141130.109056  48796.775723
# 7   -53.477477  466601.099099  228133.333333  142790.090090  49150.450450
# 8   -70.318634  473883.902560  232126.671408  144450.071124  49504.125178
# 9   -87.159791  481166.706022  236120.009483  146110.052157  49857.799905
# 10 -104.000948  488449.509483  240113.347558  147770.033191  50211.474633
# 11 -120.842105  495732.312945  244106.685633  149430.014225  50565.149360
# ...

# %%
df.columns
# Out:
# Index(['Production (TJ)', 'Consumption (TJ)', 'Transportation (TJ)',
#        'Industry  (TJ)', 'Residential (TJ)', 'Commercial (TJ)',
#        'Population growth (%)', 'Population density (%)', 'GDP (billion USD)',
#        'Installed capacity of renewable energies (MW)', 'Reserves (TJ)',
#        'Oil & products Imports (TJ)', 'Population growth (%).1',
#        'GDP (Trillion USD)', 'Oil prices ($/MW)', 'Energy Security (%)',
#        'Energy Equity (%)', 'Environmental Sustainability (%)'],
#       dtype='object')

# %% [markdown]
# **Best Model**

# %% [markdown]
# **Logistic Regression**

# %%
#Category 1
tr = df['Transportation (TJ)']
ind = df['Industry  (TJ)']
res = df['Residential (TJ)']
com = df['Commercial (TJ)']
#prod = df['Transportation (TJ)', 'Industry (TJ)', 'Residential (TJ)', 'Commercial (TJ)']
#prod = prod[:-10]
cat1 = pd.concat([tr, ind, res, com], axis = 1)
cat1
# Out:
#     Transportation (TJ)  Industry  (TJ)  Residential (TJ)  Commercial (TJ)
# 0                 28400           42900             27200            23000
# 1                 28400           49800             28400            24300
# 2                 30500           46100             29800            26000
# 3                 31900           50400             31800            27700
# 4                 35700           56500             34100            30000
# 5                 36500           60900             36400            31100
# 6                 40500           67500             38600            32700
# 7                 36400           71800             38700            33500
# 8                 35900           64700             39000            34000
# 9                 38700           64200             41500            35000
# 10                37500           67400             43500            36000
# ...

# %%
Linear_model = LinearRegression()
Linear_model.fit(X_train, prod[:-10])
predicted_Linear = Linear_model.predict(X_test)

# %%
predicted_Linear
# Out:
# array([[152259.90990991, 111250.45045045,  42430.63063063,
#          76710.36036036],
#        [156253.24798483, 112910.43148412,  42784.30535799,
#          78279.32669512],
#        [160246.58605974, 114570.41251778,  43137.98008535,
#          79848.29302987],
#        [164239.92413466, 116230.39355145,  43491.65481271,
#          81417.25936463],
#        [168233.26220958, 117890.37458511,  43845.32954007,
#          82986.22569938],
#        [172226.60028449, 119550.35561878,  44199.00426743,
#          84555.19203414],
#        [176219.93835941, 121210.33665244,  44552.67899478,
#          86124.1583689 ],
#        [180213.27643433, 122870.31768611,  44906.35372214,
#          87693.12470365],
#        [184206.61450925, 124530.29871977,  45260.0284495 ,
#          89262.09103841],
#        [188199.95258416, 126190.27975344,  45613.70317686,
#          90831.05737316]])

# %%
#Category 2
tr = df['Population growth (%)']
ind = df['Population density (%)']
res = df['GDP (billion USD)']
#prod = df['Transportation (TJ)', 'Industry (TJ)', 'Residential (TJ)', 'Commercial (TJ)']
#prod = prod[:-10]
cat2 = pd.concat([tr, ind, res], axis = 1)
cat2
# Out:
#     Population growth (%)  Population density (%)  GDP (billion USD)
# 0                    2.08                   24.40              6.242
# 1                    2.12                   24.92              7.675
# 2                    2.18                   25.47              8.985
# 3                    2.24                   26.05              9.584
# 4                    2.29                   26.65             11.050
# 5                    2.33                   27.28             13.240
# 6                    2.37                   27.93             15.910
# 7                    2.39                   28.61             21.730
# 8                    2.42                   29.31             17.790
# 9                    2.43                   30.03             17.690
# 10                   2.41                   30.77             16.250
# 11                   2.33                   31.49             14.820
# 12                   2.23                   32.20             14.990
# ...

# %%
Linear_model = LinearRegression()
Linear_model.fit(X_train, cat2[:-10])
predicted_Linear = Linear_model.predict(X_test)

# %%
predicted_Linear
# Out:
# array([[ 0.95076577, 47.09135135, 70.97087838],
#        [ 0.90858701, 47.69644381, 72.90660597],
#        [ 0.86640825, 48.30153627, 74.84233357],
#        [ 0.82422949, 48.90662873, 76.77806117],
#        [ 0.78205073, 49.51172119, 78.71378876],
#        [ 0.73987198, 50.11681366, 80.64951636],
#        [ 0.69769322, 50.72190612, 82.58524395],
#        [ 0.65551446, 51.32699858, 84.52097155],
#        [ 0.6133357 , 51.93209104, 86.45669915],
#        [ 0.57115695, 52.5371835 , 88.39242674]])

# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Research Energy Consumption Production/Factors.csv"
df = pd.read_csv(path, header=1)
df
# Out:
#     Years  Production (TJ)  Consumption (TJ)  Transportation (TJ)  \
# 0    1973             1600             84300                28400
# 1    1974             1000             93800                28400
# 2    1975              800             96000                30500
# 3    1976              400            103000                31900
# 4    1977              900            116300                35700
# 5    1978              900            122500                36500
# 6    1979              700            134900                40500
# 7    1980              500            134200                36400
# 8    1981              700            124300                35900
# 9    1982              600            129100                38700
# 10   1983              700            126000                37500
# 11   1984              600            124100                36100
# 12   1985              900            124600                36600
# ...

# %%
df.insert?

# %%
production = df['Production (TJ)']
consumption = df['Consumption (TJ)']

# %%
#cols = df.columns(['Population growth (%)', 'Population density (%)',	'GDP(billion USD)'])
pop_dens = df['Population growth (%)']
pop_growth = df['Population growth (%)']
gdp_mor = df['GDP(billion USD)']
#morocco_data = pd.merge(pd.merge(pop_dens, pop_growth), gdp_mor)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GDP(billion USD)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
production.tail()
# Out:
# 42    209
# 43    209
# 44    194
# 45    203
# 46    181
# Name: Production (TJ), dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
#2D DFs to TimeSeries

# %%
#Data for the Consumption Prediction
X_train, X_test, y_train, y_test = train_test_split(df1, production, random_state=47, test_size=0.25)

# %% [markdown]
# **Decision Regressor**

# %%
tree_model_Production = DecisionTreeRegressor(random_state=47)
tree_model_Production.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
predicted_decision_reg_Production = tree_model_Production.predict(X_test)
predicted_decision_reg_Production.shape
# Out:
# (12,)

# %%
predicted_decision_reg_Production
# Out:
# array([461., 377., 377., 377., 419., 900., 461., 600., 461., 461., 700.,
#        335.])

# %%
from sklearn import metrics

tree_model_Production.score(X_test, y_test)
# Out:
# 0.631596198192157

# %% [markdown]
# **Linear Regression**

# %%
from pandas.core.common import random_state
Linear_model_Production = LinearRegression()
Linear_model_Production.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_Linear_Production = Linear_model_Production.predict(X_test)
predicted_Linear_Production.shape
# Out:
# (12,)

# %%
predicted_Linear_Production
# Out:
# array([352.88686815, 175.06525537, 318.54525612, 254.57785038,
#        484.60840956, 532.50483304, 426.70389597, 667.64542291,
#        304.21498319, 564.58317477, 653.73645586, 400.67563404])

# %%
from sklearn import metrics

Linear_model_Production.score(X_test, y_test)
# Out:
# 0.20001559766590082

# %% [markdown]
# **Logistic Regression**

# %%
Logistic_model_Production = LogisticRegression(max_iter=20)
Logistic_model_Production.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression(max_iter=20)

# %%
predicted_Logistic_Production = Logistic_model_Production.predict(X_test)
predicted_Logistic_Production.shape
# Out:
# (12,)

# %%
predicted_Logistic_Production
# Out:
# array([419, 209, 419, 209, 461, 700, 209, 700, 419, 461, 700, 419])

# %%
from sklearn.metrics import accuracy_score

Logistic_model_Production.score(X_test, y_test)
# Out:
# 0.16666666666666666
